# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER,LATITUDE_FORMATTER
import os,errno
import sys
import cartopy.feature as cfeature
import matplotlib.ticker as mticker
import pandas as pd
import datetime as dt
from scipy.ndimage.measurements import label
from math import sin, cos, sqrt, atan2, radians
import geopy.distance
# %matplotlib inline

dir2='/thorncroftlab_rit/ahenny/rain/'
dir1='/thorncroftlab_rit/ahenny/rain/US/ghcnd_all/'
dir='/thorncroftlab_rit/ahenny/rain/DISSERTATION_SCRIPTS_RESULTS/'

# %%
season='summer'
yrs_neusa=np.arange(1979,2020,1)
count_t1=0
count_t2=0
count_t3=0
count_t4=0
count_t5=0
count_t6=0
count_t7=0
count_t8=0
count_t9=0
count_t10=0
count_t11=0
for i in range(len(yrs_neusa)):
    year=yrs_neusa[i]
    print(year)
    if i>0:
        ds.close()
    ds=xr.open_dataset(dir+'day_classifications_neusa_'+season+'_ep_days'+'.nc')

    try:
        dates_t1=ds['dates_t1_all'].values
        dates_t1=pd.DatetimeIndex(dates_t1)
        if count_t1>0:
            dates_t1_all=dates_t1_all.append(dates_t1)
        else:
            dates_t1_all=dates_t1
            count_t1=1
    except:
        pass
    
    try:
        dates_t2=ds['dates_t2_all'].values
        dates_t2=pd.DatetimeIndex(dates_t2)
        if count_t2>0:
            dates_t2_all=dates_t2_all.append(dates_t2)
        else:
            dates_t2_all=dates_t2
            count_t2=1
    except:
        pass
    
    try:
        dates_t3=ds['dates_t3_all'].values
        dates_t3=pd.DatetimeIndex(dates_t3)
        if count_t3>0:
            dates_t3_all=dates_t3_all.append(dates_t3)
        else:
            dates_t3_all=dates_t3
            count_t3=1
    except:
        pass
    
    try:
        dates_t4=ds['dates_t4_all'].values
        dates_t4=pd.DatetimeIndex(dates_t4)
        if count_t4>0:
            dates_t4_all=dates_t4_all.append(dates_t4)
        else:
            dates_t4_all=dates_t4
            count_t4=1
    except:
        pass
    
    try:
        dates_t5=ds['dates_t5_all'].values
        dates_t5=pd.DatetimeIndex(dates_t5)
        if count_t5>0:
            dates_t5_all=dates_t5_all.append(dates_t5)
        else:
            dates_t5_all=dates_t5
            count_t5=1
    except:
        pass
    
    try:
        dates_t6=ds['dates_t6_all'].values
        dates_t6=pd.DatetimeIndex(dates_t6)
        if count_t6>0:
            dates_t6_all=dates_t6_all.append(dates_t6)
        else:
            dates_t6_all=dates_t6
            count_t6=1
    except:
        pass
    
    try:
        dates_t7=ds['dates_t7_all'].values
        dates_t7=pd.DatetimeIndex(dates_t7)
        if count_t7>0:
            dates_t7_all=dates_t7_all.append(dates_t7)
        else:
            dates_t7_all=dates_t7
            count_t7=1
    except:
        pass
    
    try:
        dates_t8=ds['dates_t8_all'].values
        dates_t8=pd.DatetimeIndex(dates_t8)
        if count_t8>0:
            dates_t8_all=dates_t8_all.append(dates_t8)
        else:
            dates_t8_all=dates_t8
            count_t8=1
    except:
        pass
    
    try:
        dates_t9=ds['dates_t9_all'].values
        dates_t9=pd.DatetimeIndex(dates_t9)
        if count_t9>0:
            dates_t9_all=dates_t9_all.append(dates_t9)
        else:
            dates_t9_all=dates_t9
            count_t9=1
    except:
        pass
    
    try:
        dates_t10=ds['dates_t10_all'].values
        dates_t10=pd.DatetimeIndex(dates_t10)
        if count_t10>0:
            dates_t10_all=dates_t10_all.append(dates_t10)
        else:
            dates_t10_all=dates_t10
            count_t10=1
    except:
        pass
    
    try:
        dates_t11=ds['dates_t11_all'].values
        dates_t11=pd.DatetimeIndex(dates_t11)
        if count_t11>0:
            dates_t11_all=dates_t11_all.append(dates_t11)
        else:
            dates_t11_all=dates_t11
            count_t11=1
    except:
        pass

thresh_choose=95
area_threshold_choose=95
season_choose=season

ds1=xr.open_dataset(dir+'extreme_days_ghcnd_'+str(thresh_choose)+'_'+str(area_threshold_choose)+'_'+season_choose+'.nc')
lats=ds1['lats'].values.tolist()
lons=ds1['lons'].values.tolist()
lons=[x+360. for x in lons]
dates=ds1['dates'].values
dates_unique=list(set(dates))
dates_unique=pd.DatetimeIndex(dates_unique).sort_values()
stations=ds1['stations'].values.tolist()
obs=ds1['obs'].values.tolist()
print(dates_unique)

# %%
ar_yesno=[]
ivt_yesno=[]
tc_yesno=[]
tc_linked_ar_yesno=[]
tc_remnant_linked_ar_yesno=[]
tc_remnant_ar_combo_yesno=[]
tc_ar_combo_yesno=[]
tc_linked_ivt_yesno=[]
tc_remnant_linked_ivt_yesno=[]
other_yesno=[]
tc_remnants_yesno=[]

for i in range(len(dates_unique)):
    if dates_unique[i] in dates_t1_all:
        ar_yesno.append(1)
        tc_linked_ar_yesno.append(0)
        tc_remnant_linked_ar_yesno.append(0)
        tc_yesno.append(0)
        tc_ar_combo_yesno.append(0)
        tc_remnant_ar_combo_yesno.append(0)
        tc_remnants_yesno.append(0)
        ivt_yesno.append(0)
        tc_linked_ivt_yesno.append(0)
        tc_remnant_linked_ivt_yesno.append(0)
        other_yesno.append(0)
    if dates_unique[i] in dates_t2_all:
        ar_yesno.append(0)
        tc_linked_ar_yesno.append(1)
        tc_remnant_linked_ar_yesno.append(0)
        tc_yesno.append(0)
        tc_ar_combo_yesno.append(0)
        tc_remnant_ar_combo_yesno.append(0)
        tc_remnants_yesno.append(0)
        ivt_yesno.append(0)
        tc_linked_ivt_yesno.append(0)
        tc_remnant_linked_ivt_yesno.append(0)
        other_yesno.append(0)
    if dates_unique[i] in dates_t3_all:
        ar_yesno.append(0)
        tc_linked_ar_yesno.append(0)
        tc_remnant_linked_ar_yesno.append(1)
        tc_yesno.append(0)
        tc_ar_combo_yesno.append(0)
        tc_remnant_ar_combo_yesno.append(0)
        tc_remnants_yesno.append(0)
        ivt_yesno.append(0)
        tc_linked_ivt_yesno.append(0)
        tc_remnant_linked_ivt_yesno.append(0)
        other_yesno.append(0)
    if dates_unique[i] in dates_t4_all:
        ar_yesno.append(0)
        tc_linked_ar_yesno.append(0)
        tc_remnant_linked_ar_yesno.append(0)
        tc_yesno.append(1)
        tc_ar_combo_yesno.append(0)
        tc_remnant_ar_combo_yesno.append(0)
        tc_remnants_yesno.append(0)
        ivt_yesno.append(0)
        tc_linked_ivt_yesno.append(0)
        tc_remnant_linked_ivt_yesno.append(0)
        other_yesno.append(0)
    if dates_unique[i] in dates_t5_all:
        ar_yesno.append(0)
        tc_linked_ar_yesno.append(0)
        tc_remnant_linked_ar_yesno.append(0)
        tc_yesno.append(0)
        tc_ar_combo_yesno.append(1)
        tc_remnant_ar_combo_yesno.append(0)
        tc_remnants_yesno.append(0)
        ivt_yesno.append(0)
        tc_linked_ivt_yesno.append(0)
        tc_remnant_linked_ivt_yesno.append(0)
        other_yesno.append(0)
    if dates_unique[i] in dates_t6_all:
        ar_yesno.append(0)
        tc_linked_ar_yesno.append(0)
        tc_remnant_linked_ar_yesno.append(0)
        tc_yesno.append(0)
        tc_ar_combo_yesno.append(0)
        tc_remnant_ar_combo_yesno.append(1)
        tc_remnants_yesno.append(0)
        ivt_yesno.append(0)
        tc_linked_ivt_yesno.append(0)
        tc_remnant_linked_ivt_yesno.append(0)
        other_yesno.append(0)
    if dates_unique[i] in dates_t7_all:
        ar_yesno.append(0)
        tc_linked_ar_yesno.append(0)
        tc_remnant_linked_ar_yesno.append(0)
        tc_yesno.append(0)
        tc_ar_combo_yesno.append(0)
        tc_remnant_ar_combo_yesno.append(0)
        tc_remnants_yesno.append(1)
        ivt_yesno.append(0)
        tc_linked_ivt_yesno.append(0)
        tc_remnant_linked_ivt_yesno.append(0)
        other_yesno.append(0)
    if dates_unique[i] in dates_t8_all:
        ar_yesno.append(0)
        tc_linked_ar_yesno.append(0)
        tc_remnant_linked_ar_yesno.append(0)
        tc_yesno.append(0)
        tc_ar_combo_yesno.append(0)
        tc_remnant_ar_combo_yesno.append(0)
        tc_remnants_yesno.append(0)
        ivt_yesno.append(1)
        tc_linked_ivt_yesno.append(0)
        tc_remnant_linked_ivt_yesno.append(0)
        other_yesno.append(0)
    if dates_unique[i] in dates_t9_all:
        ar_yesno.append(0)
        tc_linked_ar_yesno.append(0)
        tc_remnant_linked_ar_yesno.append(0)
        tc_yesno.append(0)
        tc_ar_combo_yesno.append(0)
        tc_remnant_ar_combo_yesno.append(0)
        tc_remnants_yesno.append(0)
        ivt_yesno.append(0)
        tc_linked_ivt_yesno.append(1)
        tc_remnant_linked_ivt_yesno.append(0)
        other_yesno.append(0)
    if dates_unique[i] in dates_t10_all:
        ar_yesno.append(0)
        tc_linked_ar_yesno.append(0)
        tc_remnant_linked_ar_yesno.append(0)
        tc_yesno.append(0)
        tc_ar_combo_yesno.append(0)
        tc_remnant_ar_combo_yesno.append(0)
        tc_remnants_yesno.append(0)
        ivt_yesno.append(0)
        tc_linked_ivt_yesno.append(0)
        tc_remnant_linked_ivt_yesno.append(1)
        other_yesno.append(0)
    if dates_unique[i] in dates_t11_all:
        ar_yesno.append(0)
        tc_linked_ar_yesno.append(0)
        tc_remnant_linked_ar_yesno.append(0)
        tc_yesno.append(0)
        tc_ar_combo_yesno.append(0)
        tc_remnant_ar_combo_yesno.append(0)
        tc_remnants_yesno.append(0)
        ivt_yesno.append(0)
        tc_linked_ivt_yesno.append(0)
        tc_remnant_linked_ivt_yesno.append(0)
        other_yesno.append(1)

# %%
#check correct value!
print(sum(ar_yesno)+sum(tc_linked_ar_yesno)+sum(tc_remnant_linked_ar_yesno)+sum(tc_yesno)+sum(tc_ar_combo_yesno)+
      sum(tc_remnant_ar_combo_yesno)+sum(tc_remnants_yesno)+sum(ivt_yesno)+sum(tc_linked_ivt_yesno)+
     sum(tc_remnant_linked_ivt_yesno)+sum(other_yesno))

# %%
print(season)
dk=xr.Dataset()
dk['ar_yesno']=(('time'),ar_yesno)
dk['tc_linked_ar_yesno']=(('time'),tc_linked_ar_yesno)
dk['tc_remnant_linked_ar_yesno']=(('time'),tc_remnant_linked_ar_yesno)
dk['tc_yesno']=(('time'),tc_yesno)
dk['tc_ar_combo_yesno']=(('time'),tc_ar_combo_yesno)
dk['tc_remnant_ar_combo_yesno']=(('time'),tc_remnant_ar_combo_yesno)
dk['tc_remnants_yesno']=(('time'),tc_remnants_yesno)
dk['ivt_yesno']=(('time'),ivt_yesno)
dk['tc_linked_ivt_yesno']=(('time'),tc_linked_ivt_yesno)
dk['tc_remnant_linked_ivt_yesno']=(('time'),tc_remnant_linked_ivt_yesno)
dk['other_yesno']=(('time'),other_yesno)
dk.coords['time']=dates_unique
try:
    os.remove(dir+'neusa_ep_days_stats_seasonal_ep_days_'+season+'.nc')
except OSError:
    pass
dk.to_netcdf(dir+'neusa_ep_days_stats_seasonal_ep_days_'+season+'.nc',mode='w',format='NETCDF4')

# %%
print(dates_unique)

# %%
print(ar_yesno)
